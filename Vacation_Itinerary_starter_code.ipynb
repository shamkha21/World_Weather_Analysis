# %% [markdown]
# # Deliverable 3. Create a Travel Itinerary Map
#
# ----
#
# 1. Create a folder called `Vacation_Itinerary` to store all the files for this deliverable.
#
# 2. Download the `Vacation_Itinerary_starter_code.ipynb` file into your `Vacation_Itinerary` folder and rename it `Vacation_Itinerary.ipynb`.
#
# 3. Make sure the initial dependencies and the Geoapify API key are imported.
#
# 4. From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`.
#
# 5. Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
#     * The point's size should be the maximum temperature for the city
#
#     * The point's color should be the city's name
#
#     * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.
#
# 6. From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.
#
#     > **Hint:** You will start and end the route in the same city, so the `vacation_start` and `vacation_end` DataFrames will be in the same city.
#
# 7. Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details.
#
# 8. Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`.
#
#     > **Hint:** You'll use this DataFrame to create a map using GeoViews, so recall that the first column should be the longitude, and the second the latitude.
#
# 9. Use GeoViews to create a map that shows the four cities in the itinerary.
#
# 10. Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop.
#
#     > **Hint:** You can note that the `mode` parameter is set to `drive`, you can play around with other modes as it's shown in [the "Travel modes" table](https://apidocs.geoapify.com/docs/routing/#api) in the Geoapify Routing API documentation.
#
# 11. Use the Geoapify Routing API to retrieve the route's directions for your itinerary.
#
# 12. From the JSON response, store the route's legs coordinates in a variable called `legs`.
#
# 13. Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude values into two Python lists named `longitude` and `latitude`.
#
# 14. Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`.
#
# 15. Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map.
#
# 16. Use the asterisk operator to display a composed plot that shows the itinerary's route over the map containing the cities.
#
# 17. Save your map to the `Vacation_Itinerary` folder as `WeatherPy_travel_map.png`.
#
# ---

# %% [markdown]
# ## Make sure the initial dependencies and the Geoapify API key are imported

# %%
# Dependencies and Setup
import geoviews as gv
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From your `Vacation_Search` folder from Deliverable 2, import the `WeatherPy_vacation.csv` file as a DataFrame named `vacation_df`

# %%
# Read the WeatherPy_vacation.csv into a DataFrame
vacation_df =pd.read_csv("WeatherPy_database.csv")

# Display sample data
vacation_df.head(50)
# Out:
#     City_ID                         City Country      Lat       Lng  Max Temp  \
# 0         0                         Hilo      US  19.7297 -155.0900     79.29
# 1         1                 Sandnessjoen      NO  66.0217   12.6316     44.65
# 2         2                    Mont-Dore      NC -22.2833  166.5833     78.01
# 3         3                        Alofi      NU -19.0595 -169.9187     76.89
# 4         4            Port-Aux-Francais      TF -49.3500   70.2167     41.05
# 5         5  Edinburgh Of The Seven Seas      SH -37.0676  -12.3116     64.44
# 6         6                         Daru      PG  -9.0763  143.2092     77.29
# 7         7                        Bumba      CD   2.1833   22.4667     78.42
# 8         8                  Yellowknife      CA  62.4560 -114.3525     37.92
# 9         9                       Eureka      US  40.8021 -124.1637     56.19
# 10       10                     Sinabang      ID   2.4803   96.3801     80.71
# 11       11                      Isangel      VU -19.5500  169.2667     77.59
# 12       12                Blackmans Bay      AU -43.0167  147.3167     49.73
# 13       13               Puerto Natales      CL -51.7236  -72.4875     55.85
# 14       14                       Avarua      CK -21.2078 -159.7750     77.05
# 15       15                        Yaren      NR  -0.5472  166.9160     83.57
# 16       16                        Onega      RU  63.9061   38.1404     34.07
# 17       17                     Waitangi      NZ -43.9535 -176.5597     61.83
# 18       18                    Adamstown      PN -25.0660 -130.1015     76.82
# 19       19                     Sisimiut      GL  66.9395  -53.6735     21.43
# 20       20                       Taltal      CL -25.4000  -70.4833     69.04
# 21       21           Severo-Yeniseyskiy      RU  60.3725   93.0408      0.16
# 22       22                     Afaahiti      PF -17.7500 -149.2833     85.87
# 23       23               Margaret River      AU -33.9500  115.0667     54.84
# 24       24                  Kapuskasing      CA  49.4169  -82.4331     30.29
# 25       25                 Punta Arenas      CL -53.1500  -70.9167     53.62
# 26       26                        Tabas      IR  33.5959   56.9244     70.02
# 27       27                       Newman      US  37.3138 -121.0208     62.24
# 28       28            Wailua Homesteads      US  22.0669 -159.3780     77.76
# 29       29              Remire-Montjoly      GF   4.9167  -52.2667     77.04
# 30       30                  West Island      CC -12.1568   96.8225     80.56
# 31       31                        Utrik      MH  11.2278  169.8474     79.84
# 32       32                    Ilulissat      GL  69.2167  -51.1000     23.02
# 33       33                  Olonkinbyen      SJ  70.9221   -8.7187     35.56
# 34       34                 Puerto Ayora      EC  -0.7393  -90.3518     85.96
# 35       35                       Abalak      RU  58.1286   68.5944     27.18
# 36       36       Hawaiian Paradise Park      US  19.5933 -154.9731     76.89
# 37       37                   Walvis Bay     NaN -22.9575   14.5053     69.94
# 38       38                        Luena      AO -11.7833   19.9167     63.73
# 39       39                     Tolanaro      MG -25.0319   46.9987     75.27
# 40       40                  Nova Vicosa      BR -17.8919  -39.3719     83.23
# 41       41                     Djibouti      DJ  11.5000   42.5000     75.58
# 42       42                          Kas      TR  36.2018   29.6377     58.10
# 43       43                     Cardigan      GB  52.0847   -4.6591     57.13
# 44       44                   Bredasdorp      ZA -34.5322   20.0403     62.62
# 45       45                       Kapa'A      US  22.0752 -159.3190     79.11
# 46       46                     Hermanus      ZA -34.4187   19.2345     57.79
# 47       47                       Kodiak      US  57.7900 -152.4072     38.71
# 48       48                       Uturoa      PF -16.7333 -151.4333     82.35
# 49       49                 Stephenville      US  32.2207  -98.2023     86.25
#
#     Humidity  Cloudiness  Wind Speed                 Date
# 0         82          40       16.11  2023-04-19 19:32:04
# 1         89          75        8.05  2023-04-19 19:35:54
# 2         99          35        3.18  2023-04-19 19:35:56
# 3        100         100        6.91  2023-04-19 19:35:57
# 4         68          52       34.90  2023-04-19 19:35:58
# 5         74         100       21.65  2023-04-19 19:35:59
# 6         86          92        5.30  2023-04-19 19:36:00
# 7         69          95        3.04  2023-04-19 19:36:02
# 8         48           0        9.22  2023-04-19 19:36:03
# 9         58          17        5.01  2023-04-19 19:33:20
# 10        79         100        5.01  2023-04-19 19:36:05
# 11        75         100        2.37  2023-04-19 19:36:07
# 12        74          93        8.59  2023-04-19 19:36:08
# 13        50          75       32.21  2023-04-19 19:31:26
# 14        88         100        6.91  2023-04-19 19:36:10
# 15        74         100       12.53  2023-04-19 19:36:12
# 16        98          99        7.34  2023-04-19 19:36:13
# 17        92         100        8.99  2023-04-19 19:36:14
# 18        75          70        7.94  2023-04-19 19:36:16
# 19        79          92        6.20  2023-04-19 19:36:17
# 20        69          24        3.80  2023-04-19 19:36:18
# 21       100          97        4.43  2023-04-19 19:36:19
# 22        80         100       18.28  2023-04-19 19:36:21
# 23        62           0        7.76  2023-04-19 19:36:22
# 24        74          75       18.41  2023-04-19 19:36:23
# 25        62          40       37.98  2023-04-19 19:36:24
# 26        19           0        4.61  2023-04-19 19:36:25
# 27        49           1        8.01  2023-04-19 19:36:27
# 28        69          20        8.05  2023-04-19 19:36:28
# 29        94          20        4.61  2023-04-19 19:36:29
# 30        82         100       22.66  2023-04-19 19:36:30
# 31        79         100       19.80  2023-04-19 19:36:32
# 32        86         100        5.75  2023-04-19 19:36:33
# 33        92          11       18.14  2023-04-19 19:36:34
# 34       100         100       11.01  2023-04-19 19:36:35
# 35        62          28        4.74  2023-04-19 19:36:37
# 36        94          40       16.11  2023-04-19 19:36:38
# 37        56           5       10.38  2023-04-19 19:35:25
# 38        68          14        4.23  2023-04-19 19:36:40
# 39        88          20        6.91  2023-04-19 19:36:42
# 40        81          17       13.58  2023-04-19 19:36:43
# 41        75          21       13.58  2023-04-19 19:36:44
# 42        72           0       10.42  2023-04-19 19:36:45
# 43        74           6       19.60  2023-04-19 19:36:46
# 44        65         100        2.64  2023-04-19 19:36:48
# 45        68          20        8.05  2023-04-19 19:36:49
# 46        76          99        4.99  2023-04-19 19:36:50
# 47        65          75       11.50  2023-04-19 19:33:15
# 48        79          73       16.11  2023-04-19 19:36:53
# 49        49          40       17.27  2023-04-19 19:36:19

# %% [markdown]
# ## Use GeoViews to create a map that shows all the cities in the `vacation_df` DataFrame. Configure the map as follows:
#
# * The point's size should be the maximum temperature for the city
#
# * The point's color should be the city's name
#
# * Use the `hover_cols` parameter to the the "Hotel Name", "Country", and "Current Description" columns to each point as additional information.

# %%
# Configure the map plot
map_plot = vacation_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City", 
    hover_cols =["Hotel Name", "Country", "Current Description"] 
     
)
 
# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country)

# %% [markdown]
# ## From the map, *choose four cities* that a customer might want to visit. They should be close together and in the same country. Use the `loc` method to create separate DataFrames for each city on the travel route.

# %%
# Create DataFrames for each city by filtering the 'vacation_df' using the loc method
vacation_start = vacation_df.loc[vacation_df["City"] == "Eureka"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Eureka"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Stephenville"] 
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Seaside"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Newman"]

# %% [markdown]
# ## Use the Pandas `concat` function to merge the DataFrame from each city in the itinerary to create a new DataFrame named `itinerary_df` to store the itinerary details

# %%
# Use the Pandas concat function to create a new DataFrame to store the itinerary details.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2, vacation_stop3], axis=0)

# %%
itinerary_df
# Out:
#      City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 9          9        Eureka      US  40.8021 -124.1637     56.19        58
# 49        49  Stephenville      US  32.2207  -98.2023     86.25        49
# 490      490       Seaside      US  36.6111 -121.8516     62.73        60
# 27        27        Newman      US  37.3138 -121.0208     62.24        49
#
#      Cloudiness  Wind Speed                 Date
# 9            17        5.01  2023-04-19 19:33:20
# 49           40       17.27  2023-04-19 19:36:19
# 490           0       13.80  2023-04-19 20:06:02
# 27            1        8.01  2023-04-19 19:36:27

# %% [markdown]
# ## Use the Pandas `copy` function to create a new DataFrame named `waypoints_df` to store the longitude and latitude for each city in `itinerary_df`

# %%
# Create a Pandas DataFrame to store the latitude and longitude for each city in the itineray
waypoints_df = itinerary_df[['Lng','Lat']].copy()

# Display sample data
waypoints_df.head()
# Out:
#           Lng      Lat
# 9   -124.1637  40.8021
# 49   -98.2023  32.2207
# 490 -121.8516  36.6111
# 27  -121.0208  37.3138

# %% [markdown]
# ## Use GeoViews to create map that shows the four cities in the itinerary

# %%
# Configure the map plot by using the itineraty_df
waypoints_map = itinerary_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
)

# %%
# Display the route_map
waypoints_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %% [markdown]
# ## Next, you'll use the Geoapify Routing API to find a route between the cities in the itinerary. Review the code that sets the initial parameters and fetches the coordinates from each city to define the `waypoints` parameter by using a `for` loop

# %%
# Set parameters to trace the route
radius = 5000
params = {
    "mode":"drive",
    "apiKey": geoapify_key,
}

# %%
# Set an empty waypoints String variable
waypoints = ""

# Iterate through the route_df DataFrame to define the waypoints
for index, row in waypoints_df.iterrows():
    waypoints = waypoints + str(row["Lat"]) + "," + str(row["Lng"]) + "|"

# Delete the last character from the string
waypoints = waypoints[:-1]

# Add the waypoints to the params dictionary
params["waypoints"] = waypoints

# Display the params dictionary
params
# Out:
# {'mode': 'drive',
#  'apiKey': '9875741f6fcf49a7a3665806c2982afb',
#  'waypoints': '40.8021,-124.1637|32.2207,-98.2023|36.6111,-121.8516|37.3138,-121.0208'}

# %% [markdown]
# ## Use the Geoapify Routing API to retrieve the route's directions for your itinerary

# %%
# Set up the base URL for the Geoapify Places API.
base_url = "https://api.geoapify.com/v1/routing"

# Make request and retrieve the JSON data by using the params dictionaty
route_response = requests.get(base_url, params=params)

# Convert the API response to JSON format
route_response = route_response.json() 
 
print(route_response)
# Out:
# {'features': [{'type': 'Feature', 'properties': {'mode': 'drive', 'waypoints': [{'location': [-124.1637, 40.8021], 'original_index': 0}, {'location': [-98.2023, 32.2207], 'original_index': 1}, {'location': [-121.8516, 36.6111], 'original_index': 2}, {'location': [-121.0208, 37.3138], 'original_index': 3}], 'units': 'metric', 'distance': 5891149, 'distance_units': 'meters', 'time': 195625.331, 'legs': [{'distance': 3127223, 'time': 103786.359, 'steps': [{'from_index': 0, 'to_index': 2, 'distance': 79, 'time': 5.815, 'instruction': {'text': 'Drive south on H Street.'}}, {'from_index': 2, 'to_index': 4, 'distance': 92, 'time': 15.572, 'instruction': {'text': 'Turn right onto 6th Street.'}}, {'from_index': 4, 'to_index': 8, 'distance': 191, 'time': 24.493, 'instruction': {'text': 'Turn right onto G Street.'}}, {'from_index': 8, 'to_index': 4461, 'distance': 242174, 'time': 9028.492, 'instruction': {'text': 'Turn left onto US 101/4th Street. Continue on US 101.'}}, {'from_index': 4461, 'to_index': 6675, 'distance': 166999, 'time': 5873.154, 'instruction': {'text': 'Keep left to stay on US 101 South.'}}, {'from_index': 6675, 'to_index': 7246, 'distance': 27935, 'time': 1047.992, 'instruction': {'text': 'Keep right to take exit 451B onto I 580 toward Richmond Bridge/Oakland.'}}, {'from_index': 7246, 'to_index': 7285, 'distance': 476, 'time': 19.261, 'instruction': {'text': 'Keep left to take Interstate Highway 80 toward Downtown Oakland/Hayward/Stockton.'}}, {'from_index': 7285, 'to_index': 8502, 'distance': 73563, 'time': 2527.61, 'instruction': {'text': 'Keep left to take MacArthur Freeway toward Downtown Oakland/Hayward/Stockton.'}}, {'from_index': 8502, 'to_index': 8591, 'distance': 17908, 'time': 574.396, 'instruction': {'text': 'Keep right to take I 580/William Elton Brown Freeway.'}}, {'from_index': 8591, 'to_index': 9524, 'distance': 342337, 'time': 10908.923, 'instruction': {'text': 'Keep left to stay on I 580/William Elton Brown Freeway.'}}, {'from_index': 9524, 'to_index': 9532, 'distance': 543, 'time': 21.988, 'instruction': {'text': 'Take exit 239 on the right onto CA 223 toward Bear Mountain Boulevard/Arvin.'}}, {'from_index': 9532, 'to_index': 9848, 'distance': 48410, 'time': 2023.808, 'instruction': {'text': 'Turn left onto Bear Mountain Boulevard/CA 223.'}}, {'from_index': 9848, 'to_index': 11028, 'distance': 164296, 'time': 5571.654, 'instruction': {'text': 'Bear right onto CA 58.'}}, {'from_index': 11028, 'to_index': 11111, 'distance': 7254, 'time': 235.91, 'instruction': {'text': 'Keep left to take I 15 North toward I 40/Las Vegas.'}}, {'from_index': 11111, 'to_index': 17444, 'distance': 1271816, 'time': 38693.503, 'instruction': {'text': 'Keep right to take I 40.'}}, {'from_index': 17444, 'to_index': 17453, 'distance': 334, 'time': 13.539, 'instruction': {'text': 'Take exit 277 on the right onto US 84 South toward Fort Summer.'}}, {'from_index': 17453, 'to_index': 17706, 'distance': 67360, 'time': 2700.195, 'instruction': {'text': 'Turn right onto US 84/Route 66. Continue on US 84.'}}, {'from_index': 17706, 'to_index': 20987, 'distance': 445017, 'time': 16122.523, 'instruction': {'text': 'Turn left onto US 60/US 84/Sumner Avenue. Continue on US 84.'}}, {'from_index': 20987, 'to_index': 22262, 'distance': 211761, 'time': 6499.82, 'instruction': {'text': 'Keep left to stay on US 84 toward Abilene.'}}, {'from_index': 22262, 'to_index': 22270, 'distance': 289, 'time': 16.281, 'instruction': {'text': 'Take exit 370 on the right onto SH 108 South/FM 919 toward Gordon/Stephenville.'}}, {'from_index': 22270, 'to_index': 22276, 'distance': 305, 'time': 22.085, 'instruction': {'text': 'Bear left onto TX 108.'}}, {'from_index': 22276, 'to_index': 22698, 'distance': 38082, 'time': 1839.335, 'instruction': {'text': 'Turn right onto State Highway 108/TX 108. Continue on TX 108.'}}, {'from_index': 22698, 'to_index': 22698, 'distance': 0, 'time': 0, 'instruction': {'text': 'Your destination is on the right.'}}]}, {'distance': 26 ...

# %%
base_url
# Out:
# 'https://api.geoapify.com/v1/routing'

# %% [markdown]
# ## From the JSON response, store the route's legs coordinates in a variable called `legs`

# %%
# Fetch the route's legs coordinates from the JSON reponse
legs = route_response["features"][0]["geometry"]["coordinates"]

# %% [markdown]
# ## Loop through the route legs coordinates to fetch the latitude and longitude for each step. Store the latitude and longitude value into two Python lists names `longitude` and `latitude`

# %%
# Create and empty list to store the longitude of each step
longitude = []

# Create and empty list to store the latitude of step
latitude= []

# Loop through the legs coordinates to fetch the latitude and longitude for each step
for leg in legs: 
    for step in leg: 
        longitude.append(step[0]) 
        latitude.append(step[1])

# %% [markdown]
# ## Use the `longitude` and `latitude` Python lists to create a new DataFrame named `route_df`

# %%
# Create an empty DataFrame to store the steps' coordinates
route_df = pd.DataFrame()

# Add the steps' longitude and latitude from each step as columns to the DataFrame
route_df["longitude"]=longitude 
route_df["latitude"]=latitude

# Display sample data
route_df.head()
# Out:
#     longitude   latitude
# 0 -124.163799  40.802087
# 1 -124.163733  40.801803
# 2 -124.163633  40.801390
# 3 -124.164140  40.801320
# 4 -124.164717  40.801242

# %% [markdown]
# ##  Use the GeoViews `Path` function to configure a line plot by using `route_df`. Set a custom color and width for the line that may contrast with the map

# %%
# Configure the route path by using the GeoViews' Path function

# %%
# Display a composed plot by using the route_map and route_path objects
# YOUR CODE HERE
